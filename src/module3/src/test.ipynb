# %% [markdown]
# # **测试已建立的MNIST数字识别网络**

# %% [markdown]
# **测试一个神经网络包含以下步骤：**
#
# 1. *加载训练好的模型*：从已保存的文件中加载已训练好的模型及其参数，这些参数包括已学习到的权重。
#
# 2. *准备输入数据*：以与训练期间相同的方式对输入数据进行预处理。例如，进行归一化和张量转换，以确保与模型兼容。
#
# 3. *将预处理后的数据输入模型以计算预测结果*：将预处理后的数据输入模型，模型将根据其训练好的参数计算输出。输出通常是所有可能类别的概率分布。
#
# 4. *解释结果*：最后，我们可以解释结果。预测的类别通常是概率最高的类别。
#
# 此过程使模型能够泛化其学习到的知识，从而对新数据做出准确的预测。
#
# **以下为测试程序。**

# %%
import torch
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import random

# Define a transformation to convert the image to a tensor
transform = transforms.Compose([
    transforms.ToTensor()
])

# Load the test set with transformation
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=transform
)

# Load the entire model
model = torch.jit.load("model.pth")

# Set the model to evaluation mode
model.eval()

# Select 16 random indices from the test dataset
random_indices = random.sample(range(len(test_data)), 16)

# Plot the 16 randomly selected images
fig, axes = plt.subplots(4, 4, figsize=(12, 12))  # Create a 4x4 grid of subplots

for i, ax in enumerate(axes.flat):
    # Get a random image and its label
    index = random_indices[i]
    image, label = test_data[index]

    # Add a batch dimension (model expects a batch of images)
    image_batch = image.unsqueeze(0)

    # Run inference
    with torch.no_grad():
        prediction = model(image_batch)

    # Get the predicted class
    predicted_label = torch.argmax(prediction, dim=1).item()

    # Display the image with actual and predicted labels
    ax.imshow(image.squeeze(), cmap="gray")
    ax.set_title(f"Actual: {label}\nPredicted: {predicted_label}")
    ax.axis("off")  # Remove axes for clarity

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 22.5MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 597kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 5.61MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.21MB/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1486/861253950.py in <cell line: 0>()
#      18
#      19 # Load the entire model
# ---> 20 model = torch.jit.load("model.pth")
#      21
#      22 # Set the model to evaluation mode
#
# /usr/local/lib/python3.12/dist-packages/torch/jit/_serialization.py in load(f, map_location, _extra_files, _restore_shapes)
#     180     if isinstance(f, (str, os.PathLike)):
#     181         if not os.path.exists(f):
# --> 182             raise ValueError(f"The provided filename {f} does not exist")
#     183         if os.path.isdir(f):
# ...

# %% [markdown]
# 以上测试程序使用训练后的模型，从测试数据集中随机选择16个图像进行测试，并显示输出数字的真实值和预测值。
#
# **恭喜！我们已经完成了PyTorch深度学习框架的学习。**
#
# 我们已完成使用 PyTorch 模型在 MNIST 数据集上进行数字分类的训练和使用。我们使用训练数据集，在多个训练周期内优化了模型的权重，采用 CrossEntropyLoss 函数和 Adam 优化器来最小化预测误差并提高准确率，然后在测试数据集上评估模型，以评价其性能，确保模型有效学习且避免过拟合。
#
# 我们也了解了如何保存模型，并利用保存的模型进行推理。加载模型时设置为评估模式，以确保 dropout 和批归一化等在推理过程中能够正常工作。我们从 MNIST 测试数据集中随机选择了 16 张图像来评估模型在未见过的数据上的性能。对于每张选定的图像，我们使用该模型预测数字，并将预测标签与实际标签进行比较。
#
# 这一完整的流程涵盖了从模型训练和保存到推理和可视化的各个环节，展示了在 PyTorch 中构建和部署机器学习模型的端到端工作流程。它演示了如何训练模型、将其保存以及如何使用该模型对新数据进行预测。该流程可以推广到其他应用中。
